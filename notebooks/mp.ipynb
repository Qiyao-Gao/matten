# %%
from mp_api.client import MPRester

api_key = "eI9T6VpoTomSN1hoTiG4FeAW6GDsZagq"

with MPRester(api_key) as mpr:
    mats = mpr.materials
    print("materials 子接口里包含 piezo 的：", [a for a in dir(mats) if "piezo" in a.lower()])
    print("materials 子接口里包含 diel 的：",  [a for a in dir(mats) if "diel" in a.lower()])
# Out:
# materials 子接口里包含 piezo 的： ['piezoelectric']
# materials 子接口里包含 diel 的： ['dielectric']

# %%
from mp_api.client import MPRester

api_key = "eI9T6VpoTomSN1hoTiG4FeAW6GDsZagq"
mpid = "mp-1014244"

with MPRester(api_key) as mpr:
    piezo = mpr.materials.piezoelectric
    print("available_fields 前30个：", piezo.available_fields[:30])
    docs = piezo.search(material_ids=[mpid], all_fields=True)
    print(docs[0])
# Out:
# available_fields 前30个： ['builder_meta', 'nsites', 'elements', 'nelements', 'composition', 'composition_reduced', 'formula_pretty', 'formula_anonymous', 'chemsys', 'volume', 'density', 'density_atomic', 'symmetry', 'material_id', 'deprecated', 'deprecation_reasons', 'last_updated', 'origins', 'warnings', 'property_name', 'total', 'ionic', 'electronic', 'e_ij_max', 'max_direction', 'strain_for_max']
# Retrieving PiezoelectricDoc documents: 100%|██████████| 1/1 [00:00<00:00, 23696.63it/s]
# MPDataDoc<_DictLikeAccess>
# builder_meta=EmmetMeta(emmet_version='0.84.6rc5', pymatgen_version='2024.11.13', run_id='7d591b38-0601-4532-9557-832970890006', batch_id=None, database_version='2025.09.25', build_date=datetime.datetime(2025, 3, 13, 21, 26, 54, 386000, tzinfo=datetime.timezone.utc), license=None),
# nsites=4,
# elements=[Element N, Element Zn, Element Zr],
# nelements=3,
# composition=Composition('Zr1 Zn1 N2'),
# composition_reduced=Composition('Zr1 Zn1 N2'),
# formula_pretty='ZrZnN2',
# ...
